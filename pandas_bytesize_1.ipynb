# %% [markdown]
# # Pandas 🤓🐼

# %%
import pandas as pd

# %%
df = pd.read_csv('_measurements.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Full Scale', 'Full scale + 2.5cm', 'Full Scale + 10cm',
#        '1/2 Scale', '1/2 Scale + 1" ', '1/2 Scale + 4"', '1/3 Scale',
#        '1/3 scale + 1" ', '1/3 Scale + 4"', '1/4 Scale', '1/4 scale + 1" ',
#        '1/4 Scale + 4"'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'Full Scale',
#  'Full scale + 2.5cm',
#  'Full Scale + 10cm',
#  '1/2 Scale',
#  '1/2 Scale + 1" ',
#  '1/2 Scale + 4"',
#  '1/3 Scale',
#  '1/3 scale + 1" ',
#  '1/3 Scale + 4"',
#  '1/4 Scale',
#  '1/4 scale + 1" ',
#  '1/4 Scale + 4"']

# %%
df.head()
# Out:
#               Unnamed: 0  Full Scale  Full scale + 2.5cm  Full Scale + 10cm  \
# 0           Total height       154.0               156.5              164.0
# 1         Height of chin       133.0               135.5              143.0
# 2         Height L elbow        93.0                95.5              103.0
# 3         Height R elbow        94.0                96.5              104.0
# 4  Height L Pelvic point        82.5                85.0               92.5
#
#    1/2 Scale  1/2 Scale + 1"   1/2 Scale + 4"  1/3 Scale  1/3 scale + 1"   \
# 0      77.00            79.50           87.00  51.333333        53.833333
# 1      66.50            69.00           76.50  44.333333        46.833333
# 2      46.50            49.00           56.50  31.000000        33.500000
# 3      47.00            49.50           57.00  31.333333        33.833333
# 4      41.25            43.75           51.25  27.500000        30.000000
#
#    1/3 Scale + 4"  1/4 Scale  1/4 scale + 1"   1/4 Scale + 4"
# ...

# %%
df.tail()
# Out:
#                             Unnamed: 0  Full Scale  Full scale + 2.5cm  \
# 17  Width front pelvic point to back R        27.0                29.5
# 18           Width front pelvic points        24.0                26.5
# 19            Width back pelvic points        10.0                12.5
# 20                     Width shoulders        36.0                38.5
# 21                          Width face        13.0                15.5
#
#     Full Scale + 10cm  1/2 Scale  1/2 Scale + 1"   1/2 Scale + 4"  1/3 Scale  \
# 17               37.0       13.5             16.0            23.5   9.000000
# 18               34.0       12.0             14.5            22.0   8.000000
# 19               20.0        5.0              7.5            15.0   3.333333
# 20               46.0       18.0             20.5            28.0  12.000000
# 21               23.0        6.5              9.0            16.5   4.333333
#
#     1/3 scale + 1"   1/3 Scale + 4"  1/4 Scale  1/4 scale + 1"   \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             object
# Full Scale            float64
# Full scale + 2.5cm    float64
# Full Scale + 10cm     float64
# 1/2 Scale             float64
# 1/2 Scale + 1"        float64
# 1/2 Scale + 4"        float64
# 1/3 Scale             float64
# 1/3 scale + 1"        float64
# 1/3 Scale + 4"        float64
# 1/4 Scale             float64
# 1/4 scale + 1"        float64
# 1/4 Scale + 4"        float64
# dtype: object

# %%
df['Full Scale']
# Out:
# 0     154.0
# 1     133.0
# 2      93.0
# 3      94.0
# 4      82.5
# 5      85.0
# 6     124.0
# 7      86.0
# 8      88.0
# 9     132.0
# 10    124.0
# 11    124.0
# 12     39.0
# 13     40.0
# 14     80.0
# 15     17.0
# 16     23.0
# 17     27.0
# 18     24.0
# 19     10.0
# 20     36.0
# 21     13.0
# Name: Full Scale, dtype: float64

# %%
type(df['Full Scale']) # series means it is a type of
# Out:
# pandas.core.series.Series

# %%
list(df['Full Scale'])
# Out:
# [154.0,
#  133.0,
#  93.0,
#  94.0,
#  82.5,
#  85.0,
#  124.0,
#  86.0,
#  88.0,
#  132.0,
#  124.0,
#  124.0,
#  39.0,
#  40.0,
#  80.0,
#  17.0,
#  23.0,
#  27.0,
#  24.0,
#  10.0,
#  36.0,
#  13.0]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Full Scale', 'Full scale + 2.5cm', 'Full Scale + 10cm',
#        '1/2 Scale', '1/2 Scale + 1" ', '1/2 Scale + 4"', '1/3 Scale',
#        '1/3 scale + 1" ', '1/3 Scale + 4"', '1/4 Scale', '1/4 scale + 1" ',
#        '1/4 Scale + 4"'],
#       dtype='object')

# %%
df[['Full Scale']]
# Out:
#     Full Scale
# 0        154.0
# 1        133.0
# 2         93.0
# 3         94.0
# 4         82.5
# 5         85.0
# 6        124.0
# 7         86.0
# 8         88.0
# 9        132.0
# 10       124.0
# 11       124.0
# 12        39.0
# 13        40.0
# 14        80.0
# 15        17.0
# 16        23.0
# 17        27.0
# 18        24.0
# 19        10.0
# 20        36.0
# 21        13.0

# %%
type(df[['Full Scale']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Full Scale', 'Full scale + 2.5cm', 'Full Scale + 10cm',
#        '1/2 Scale', '1/2 Scale + 1" ', '1/2 Scale + 4"', '1/3 Scale',
#        '1/3 scale + 1" ', '1/3 Scale + 4"', '1/4 Scale', '1/4 scale + 1" ',
#        '1/4 Scale + 4"'],
#       dtype='object')

# %%
df[['1/2 Scale + 1" ', '1/4 Scale']] # if we are selecting multiple columns , we have to 
                                 # pass it as list
# Out:
#     1/2 Scale + 1"   1/4 Scale
# 0             79.50     38.500
# 1             69.00     33.250
# 2             49.00     23.250
# 3             49.50     23.500
# 4             43.75     20.625
# 5             45.00     21.250
# 6             64.50     31.000
# 7             45.50     21.500
# 8             46.50     22.000
# 9             68.50     33.000
# 10            64.50     31.000
# 11            64.50     31.000
# 12            22.00      9.750
# 13            22.50     10.000
# 14            42.50     20.000
# 15            11.00      4.250
# 16            14.00      5.750
# 17            16.00      6.750
# 18            14.50      6.000
# 19             7.50      2.500
# 20            20.50      9.000
# 21             9.00      3.250

# %%
df[[ '1/2 Scale', '1/2 Scale + 1" ', '1/2 Scale + 4"', '1/3 Scale',
       '1/3 scale + 1" ']]
# Out:
#     1/2 Scale  1/2 Scale + 1"   1/2 Scale + 4"  1/3 Scale  1/3 scale + 1"
# 0       77.00            79.50           87.00  51.333333        53.833333
# 1       66.50            69.00           76.50  44.333333        46.833333
# 2       46.50            49.00           56.50  31.000000        33.500000
# 3       47.00            49.50           57.00  31.333333        33.833333
# 4       41.25            43.75           51.25  27.500000        30.000000
# 5       42.50            45.00           52.50  28.333333        30.833333
# 6       62.00            64.50           72.00  41.333333        43.833333
# 7       43.00            45.50           53.00  28.666667        31.166667
# 8       44.00            46.50           54.00  29.333333        31.833333
# 9       66.00            68.50           76.00  44.000000        46.500000
# 10      62.00            64.50           72.00  41.333333        43.833333
# 11      62.00            64.50           72.00  41.333333        43.833333
# ...

# %%
df1 = pd.read_excel('_measurements.xlsx')

# %%
df1.head()
# Out:
#               Unnamed: 0  Full Scale  Full scale + 2.5cm  Full Scale + 10cm  \
# 0           Total height       154.0               156.5              164.0
# 1         Height of chin       133.0               135.5              143.0
# 2         Height L elbow        93.0                95.5              103.0
# 3         Height R elbow        94.0                96.5              104.0
# 4  Height L Pelvic point        82.5                85.0               92.5
#
#    1/2 Scale  1/2 Scale + 1"   1/2 Scale + 4"  1/3 Scale  1/3 scale + 1"   \
# 0      77.00            79.50           87.00  51.333333        53.833333
# 1      66.50            69.00           76.50  44.333333        46.833333
# 2      46.50            49.00           56.50  31.000000        33.500000
# 3      47.00            49.50           57.00  31.333333        33.833333
# 4      41.25            43.75           51.25  27.500000        30.000000
#
#    1/3 Scale + 4"  1/4 Scale  1/4 scale + 1"   1/4 Scale + 4"
# ...

# %%
df1.tail()
# Out:
#                             Unnamed: 0  Full Scale  Full scale + 2.5cm  \
# 17  Width front pelvic point to back R        27.0                29.5
# 18           Width front pelvic points        24.0                26.5
# 19            Width back pelvic points        10.0                12.5
# 20                     Width shoulders        36.0                38.5
# 21                          Width face        13.0                15.5
#
#     Full Scale + 10cm  1/2 Scale  1/2 Scale + 1"   1/2 Scale + 4"  1/3 Scale  \
# 17               37.0       13.5             16.0            23.5   9.000000
# 18               34.0       12.0             14.5            22.0   8.000000
# 19               20.0        5.0              7.5            15.0   3.333333
# 20               46.0       18.0             20.5            28.0  12.000000
# 21               23.0        6.5              9.0            16.5   4.333333
#
#     1/3 scale + 1"   1/3 Scale + 4"  1/4 Scale  1/4 scale + 1"   \
# ...

# %%
df1.dtypes
# Out:
# Unnamed: 0             object
# Full Scale            float64
# Full scale + 2.5cm    float64
# Full Scale + 10cm     float64
# 1/2 Scale             float64
# 1/2 Scale + 1"        float64
# 1/2 Scale + 4"        float64
# 1/3 Scale             float64
# 1/3 scale + 1"        float64
# 1/3 Scale + 4"        float64
# 1/4 Scale             float64
# 1/4 scale + 1"        float64
# 1/4 Scale + 4"        float64
# dtype: object

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Full Scale', 'Full scale + 2.5cm', 'Full Scale + 10cm',
#        '1/2 Scale', '1/2 Scale + 1" ', '1/2 Scale + 4"', '1/3 Scale',
#        '1/3 scale + 1" ', '1/3 Scale + 4"', '1/4 Scale', '1/4 scale + 1" ',
#        '1/4 Scale + 4"'],
#       dtype='object')

# %%
df1['Unnamed: 0']
# Out:
# 0                           Total height
# 1                         Height of chin
# 2                         Height L elbow
# 3                         Height R elbow
# 4                  Height L Pelvic point
# 5                  Height R Pelvic point
# 6                   Height Sternal Notch
# 7             Height Back L pelvic point
# 8             Height Back R pelvic point
# 9                              Height C7
# 10                     Height L shoulder
# 11                     Height R shoulder
# 12                         Height L knee
# 13                         Height R knee
# 14                     Height pubic bone
# 15             Width sternal notch to C7
# 16    Width front pelvic point to back L
# 17    Width front pelvic point to back R
# 18             Width front pelvic points
# 19              Width back pelvic points
# 20                       Width shoulders
# 21                            Width face
# Name: Unnamed: 0, dtype: object

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
type(df2['Fare'])
# Out:
# pandas.core.series.Series

# %%
df2[[ 'Pclass', 'Name', 'Sex']] # when selecting multiple columns
# Out:
#      Pclass                                               Name     Sex
# 0         3                            Braund, Mr. Owen Harris    male
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2         3                             Heikkinen, Miss. Laina  female
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4         3                           Allen, Mr. William Henry    male
# ..      ...                                                ...     ...
# 886       2                              Montvila, Rev. Juozas    male
# 887       1                       Graham, Miss. Margaret Edith  female
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female
# 889       1                              Behr, Mr. Karl Howell    male
# 890       3                                Dooley, Mr. Patrick    male
#
# [891 rows x 3 columns]

# %%
df2.to_csv('titanicdata.csv', index=False) # simple way to store the data that was og url accessed :3

# %%
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Suppose we want to filter out our numerical data aswell

# 1 Opt Manually doing it
df2[['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
# Write a python script to do it 

df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# filtering out only dtype 'object' data so we get only out catgrcal data :)
df2.dtypes[df2.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df2[df2.dtypes[df2.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df2[df2.dtypes[df2.dtypes == 'object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# what we can gather is based on the count, there are many missing data sets in
# cabin column

# %%
# We can do the same for numerical data
df2[df2.dtypes[df2.dtypes == 'int64'].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
df2[df2.dtypes[df2.dtypes == 'float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Say we want to get records from row 4 to row 10 in these 2 columns
df2[['Survived', 'Pclass']][4:11]
# Out:
#     Survived  Pclass
# 4          0       3
# 5          0       3
# 6          0       1
# 7          0       3
# 8          1       3
# 9          1       2
# 10         1       3

# %%
# Say we want to get ever 2 records from row 4 to row 10 in these 2 columns
df2[['Survived', 'Pclass']][4:11:2]
# Out:
#     Survived  Pclass
# 4          0       3
# 6          0       1
# 8          1       3
# 10         1       3

# %%
# Say we needed to add one more column
df2['new_col'] = 0

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S        0
# 1      0          PC 17599  71.2833   C85        C        0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0
# 3      0            113803  53.1000  C123        S        0
# ...

# %%
# Say we want to create a new column where we are joining/concat two columns:

df2['new_coll1'] = df2['PassengerId'] + df2['Pclass']

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_coll1
# 0      0         A/5 21171   7.2500   NaN        S        0          4
# 1      0          PC 17599  71.2833   C85        C        0          3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0          6
# ...

# %%
# Say we want to gather some insights from passenger class
pd.Categorical(df2['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df2['Survived'])
# Out:
# [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 891
# Categories (2, int64): [0, 1]

# %%
pd.Categorical(df2['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
# Say we want to find out unique values in cabin column
df2['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
# Basic queries or filtering w dataset :3
# Pass condition inside df to filter out for it, and now it returns only those records
# where age is greater than 18
df2[df2['Age'] > 18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df2)- len(df2[df2['Age'] > 18]) # 316 ppl in the ship were older than 18
# Out:
# 316

# %%
# Say We want to find out ticket fair that was less than avg - 32.204208

df2[df2['Fare'] < 32.204208]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
# Now say We want to find out ticket fair that was more than avg - 32.204208

df2[df2['Fare'] > 32.204208]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Say we would like to know who has gotten free ticket

df2[df2['Fare']== 0]['Name']
# Out:
# 179                 Leonard, Mr. Lionel
# 263               Harrison, Mr. William
# 271        Tornquist, Mr. William Henry
# 277         Parkes, Mr. Francis "Frank"
# 302     Johnson, Mr. William Cahoone Jr
# 413      Cunningham, Mr. Alfred Fleming
# 466               Campbell, Mr. William
# 481    Frost, Mr. Anthony Wood "Archie"
# 597                 Johnson, Mr. Alfred
# 633       Parr, Mr. William Henry Marsh
# 674          Watson, Mr. Ennis Hastings
# 732                Knight, Mr. Robert J
# 806              Andrews, Mr. Thomas Jr
# 815                    Fry, Mr. Richard
# 822     Reuchlin, Jonkheer. John George
# Name: Name, dtype: object

# %%
# Say we would like to know how many ppl got free ticket

len(df2[df2['Fare']== 0]['Name'])
# Out:
# 15

# %%
# Say we want to find out how many males where onboarded on the ship

df2[df2['Sex'] == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked  new_col  \
# ...

# %%
len(df2[df2['Sex'] == 'male'])
# Out:
# 577

# %%
# Say we want to find out how many females where onboarded on the ship

df2[df2['Sex'] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Say we want to find out how many ppl chose class1 ticket

df2[df2['Pclass'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Say we want to find out how many ppl survived

df2[df2['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Say we want to find out how many ppl survived

df2[df2['Survived'] == 0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
# If we wanted to find out how many females paid more than avg fares
df2[(df2['Sex'] == 'female') & (df2['Fare']>32)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# If we wanted to find out how many males paid more than avg fares
df2[(df2['Sex'] == 'female') & (df2['Fare']>32)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# If we wanted to find out how many males paid more than avg fares
df2[(df2['Sex'] == 'male') & (df2['Fare']>32)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# 35            36         0       1        Holverson, Mr. Alexander Oskar
# ..           ...       ...     ...                                   ...
# 827          828         1       2                 Mallet, Master. Andre
# 838          839         1       3                       Chip, Mr. Chang
# 846          847         0       3              Sage, Mr. Douglas Bullen
# 848          849         0       2                     Harper, Rev. John
# 867          868         0       1  Roebling, Mr. Washington Augustus II
#
#       Sex   Age  SibSp  Parch           Ticket      Fare        Cabin  \
# ...

# %%
df2[(df2['Sex'] == 'male') | (df2['Fare']>32)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
max(df2['Fare'])
# Out:
# 512.3292

# %%
# We wanted to get the name of the ppl who paid the max fare
df2[df2['Fare'] == max(df2['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df.head()
# Out:
#               Unnamed: 0  Full Scale  Full scale + 2.5cm  Full Scale + 10cm  \
# 0           Total height       154.0               156.5              164.0
# 1         Height of chin       133.0               135.5              143.0
# 2         Height L elbow        93.0                95.5              103.0
# 3         Height R elbow        94.0                96.5              104.0
# 4  Height L Pelvic point        82.5                85.0               92.5
#
#    1/2 Scale  1/2 Scale + 1"   1/2 Scale + 4"  1/3 Scale  1/3 scale + 1"   \
# 0      77.00            79.50           87.00  51.333333        53.833333
# 1      66.50            69.00           76.50  44.333333        46.833333
# 2      46.50            49.00           56.50  31.000000        33.500000
# 3      47.00            49.50           57.00  31.333333        33.833333
# 4      41.25            43.75           51.25  27.500000        30.000000
#
#    1/3 Scale + 4"  1/4 Scale  1/4 scale + 1"   1/4 Scale + 4"
# ...

# %%
df2[0:100:2] # Getting all records at even indexes
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 6             7         0       1
# 8             9         1       3
# 10           11         1       3
# 12           13         0       3
# 14           15         0       3
# 16           17         0       3
# 18           19         0       3
# 20           21         0       2
# 22           23         1       3
# 24           25         0       3
# 26           27         0       3
# 28           29         1       3
# 30           31         0       1
# 32           33         1       3
# 34           35         0       1
# 36           37         1       3
# 38           39         0       3
# 40           41         0       3
# 42           43         0       3
# 44           45         1       3
# 46           47         0       3
# 48           49         0       3
# 50           51         0       3
# ...

# %%
# Say we wanted to do row selection in a different way, from the first to the third
df2.iloc[0:2] #iloc stands for int location :)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new_col  new_coll1
# 0      0  A/5 21171   7.2500   NaN        S        0          4
# 1      0   PC 17599  71.2833   C85        C        0          3

# %%
df.loc[0:2]
# Out:
#        Unnamed: 0  Full Scale  Full scale + 2.5cm  Full Scale + 10cm  \
# 0    Total height       154.0               156.5              164.0
# 1  Height of chin       133.0               135.5              143.0
# 2  Height L elbow        93.0                95.5              103.0
#
#    1/2 Scale  1/2 Scale + 1"   1/2 Scale + 4"  1/3 Scale  1/3 scale + 1"   \
# 0       77.0             79.5            87.0  51.333333        53.833333
# 1       66.5             69.0            76.5  44.333333        46.833333
# 2       46.5             49.0            56.5  31.000000        33.500000
#
#    1/3 Scale + 4"  1/4 Scale  1/4 scale + 1"   1/4 Scale + 4"
# 0       61.333333      38.50            41.00           48.50
# 1       54.333333      33.25            35.75           43.25
# 2       41.000000      23.25            25.75           33.25

# %%
df2.iloc[0:2, ['PassengerId', 'Survived', 'Pclass']] # will always go with, default pd
                                                        # inbuilt indexes
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[212], line 1
# ----> 1 df2.iloc[0:2, ['PassengerId', 'Survived', 'Pclass']]
#
# File c:\Anaconda\lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File c:\Anaconda\lib\site-packages\pandas\core\indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# ...

# %%
df2.loc[0:2, ['PassengerId', 'Survived', 'Pclass']] # will be able to understand named indexes
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3

# %%
# Say we want to read our only tabular data in a webpage, you can do it with pandas too!
url_data = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
df3 = url_data[0]

# %%
df3.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df3.tail(4)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 671  170  245  135  86  17  75  115  685
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [4 rows x 30 columns]

# %%
df3.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3['Player']
# Out:
# 0          Quincy Acy
# 1        Jordan Adams
# 2        Steven Adams
# 3         Jeff Adrien
# 4       Arron Afflalo
#             ...
# 670    Thaddeus Young
# 671    Thaddeus Young
# 672    Thaddeus Young
# 673       Cody Zeller
# 674      Tyler Zeller
# Name: Player, Length: 675, dtype: object

# %%
df3[[ 'Pos', 'Age', 'Tm', 'G']]
# Out:
#     Pos Age   Tm   G
# 0    PF  24  NYK  68
# 1    SG  20  MEM  30
# 2     C  21  OKC  70
# 3    PF  28  MIN  17
# 4    SG  29  TOT  78
# ..   ..  ..  ...  ..
# 670  PF  26  TOT  76
# 671  PF  26  MIN  48
# 672  PF  26  BRK  28
# 673   C  22  CHO  62
# 674   C  25  BOS  82
#
# [675 rows x 4 columns]

# %%
df3.to_csv('players.csv', index=False)
